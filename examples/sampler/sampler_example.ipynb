# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Random Sample example

# %%
# This is the main function
from xopt.sampler import random_sampler

# Test function
from xopt.evaluators import test_TNK

# %%
# Get VOCS
VOCS = test_TNK.VOCS
VOCS
# Out:
# {'name': 'TNK_test',
#  'description': 'Constrainted test function TNK. See Table V in https://www.iitk.ac.in/kangal/Deb_NSGA-II.pdf',
#  'simulation': 'test_TNK',
#  'variables': {'x1': [0, 4], 'x2': [0, 3.14159]},
#  'objectives': {'y1': 'MINIMIZE', 'y2': 'MINIMIZE'},
#  'constraints': {'c1': ['GREATER_THAN', 0], 'c2': ['GREATER_THAN', 0]},
#  'constants': {'a': 'dummy_constant'},
#  'linked_variables': {'x9': 'x1'}}

# %%
# Get evaluate function
EVALUATE = test_TNK.evaluate_TNK
# ?EVALUATE
# Out:
# Signature: EVALUATE(inputs, extra_option='abc', **params)
# Docstring: <no docstring>
# File:      ~/Code/GitHub/xopt/xopt/evaluators/test_TNK.py
# Type:      function

# %%
VOCS['variables']['x1'] = [0, 4] # Extent to occasionally throw an exception

# %%
# Get a parallel executor
from concurrent.futures import ProcessPoolExecutor
executor = ProcessPoolExecutor()

# Run
results = random_sampler(executor, vocs=VOCS, evaluate_f=EVALUATE, verbose=True)
# Out:
# ███████╗ █████╗ ███╗   ███╗██████╗ ██╗     ███████╗██████╗
# ██╔════╝██╔══██╗████╗ ████║██╔══██╗██║     ██╔════╝██╔══██╗
# ███████╗███████║██╔████╔██║██████╔╝██║     █████╗  ██████╔╝
# ╚════██║██╔══██║██║╚██╔╝██║██╔═══╝ ██║     ██╔══╝  ██╔══██╗
# ███████║██║  ██║██║ ╚═╝ ██║██║     ███████╗███████╗██║  ██║
# ╚══════╝╚═╝  ╚═╝╚═╝     ╚═╝╚═╝     ╚══════╝╚══════╝╚═╝  ╚═╝
#
#
# Xopt Random Sampler
#
#
# .{'Exception': 'Input greater than 3.14159 '}
# ........{'Exception': 'Input greater than 3.14159 '}
# .10 samples completed in 0.00040 minutes
# ....{'Exception': 'Input greater than 3.14159 '}
# ....{'Exception': 'Input greater than 3.14159 '}
# ..10 samples completed in 0.00034 minutes
# ....{'Exception': 'Input greater than 3.14159 '}
# .{'Exception': 'Input greater than 3.14159 '}
# .....10 samples completed in 0.00034 minutes
# .{'Exception': 'Input greater than 3.14159 '}
# .........10 samples completed in 0.00032 minutes
# {'Exception': 'Input greater than 3.14159 '}
# .......{'Exception': 'Input greater than 3.14159 '}
# ...10 samples completed in 0.00035 minutes
# ..........10 samples completed in 0.00031 minutes
# ..........{'Exception': 'Input greater than 3.14159 '}
# 10 samples completed in 0.00029 minutes
# ..........10 samples completed in 0.00031 minutes
# {'Exception': 'Input greater than 3.14159 '}
# ..........10 samples completed in 0.00032 minutes
# .{'Exception': 'Input greater than 3.14159 '}
# ....{'Exception': 'Input greater than 3.14159 '}
# .....10 samples completed in 0.00031 minutes
# ....{'Exception': 'Input greater than 3.14159 '}
# ....{'Exception': 'Input greater than 3.14159 '}
# ..10 samples completed in 0.00035 minutes
# {'Exception': 'Input greater than 3.14159 '}
# {'Exception': 'Input greater than 3.14159 '}
# .{'Exception': 'Input greater than 3.14159 '}
# .......{'Exception': 'Input greater than 3.14159 '}
# ..10 samples completed in 0.00032 minutes

# %%
from tempfile import TemporaryDirectory
SCRATCH = TemporaryDirectory()

executor = ProcessPoolExecutor()

# Run with output path
results2 = random_sampler(executor, vocs=test_TNK.VOCS, evaluate_f=test_TNK.evaluate_TNK, output_path=SCRATCH.name, verbose=True)
# Out:
# ███████╗ █████╗ ███╗   ███╗██████╗ ██╗     ███████╗██████╗
# ██╔════╝██╔══██╗████╗ ████║██╔══██╗██║     ██╔════╝██╔══██╗
# ███████╗███████║██╔████╔██║██████╔╝██║     █████╗  ██████╔╝
# ╚════██║██╔══██║██║╚██╔╝██║██╔═══╝ ██║     ██╔══╝  ██╔══██╗
# ███████║██║  ██║██║ ╚═╝ ██║██║     ███████╗███████╗██║  ██║
# ╚══════╝╚═╝  ╚═╝╚═╝     ╚═╝╚═╝     ╚══════╝╚══════╝╚═╝  ╚═╝
#
#
# Xopt Random Sampler
#
#
# .{'Exception': 'Input greater than 3.14159 '}
# .{'Exception': 'Input greater than 3.14159 '}
# .......{'Exception': 'Input greater than 3.14159 '}
# .{'Exception': 'Input greater than 3.14159 '}
# 10 samples completed in 0.00041 minutes
# {'Exception': 'Input greater than 3.14159 '}
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-1.json
# ........{'Exception': 'Input greater than 3.14159 '}
# .{'Exception': 'Input greater than 3.14159 '}
# .10 samples completed in 0.00033 minutes
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-2.json
# ..........10 samples completed in 0.00027 minutes
# {'Exception': 'Input greater than 3.14159 '}
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-3.json
# ....{'Exception': 'Input greater than 3.14159 '}
# .{'Exception': 'Input greater than 3.14159 '}
# ...{'Exception': 'Input greater than 3.14159 '}
# ..{'Exception': 'Input greater than 3.14159 '}
# 10 samples completed in 0.00036 minutes
# {'Exception': 'Input greater than 3.14159 '}
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-4.json
# ......{'Exception': 'Input greater than 3.14159 '}
# ...{'Exception': 'Input greater than 3.14159 '}
# .10 samples completed in 0.00033 minutes
# {'Exception': 'Input greater than 3.14159 '}
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-5.json
# .........{'Exception': 'Input greater than 3.14159 '}
# .10 samples completed in 0.00032 minutes
# {'Exception': 'Input greater than 3.14159 '}
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-6.json
# .......{'Exception': 'Input greater than 3.14159 '}
# ..{'Exception': 'Input greater than 3.14159 '}
# .10 samples completed in 0.00031 minutes
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-7.json
# ....{'Exception': 'Input greater than 3.14159 '}
# .....{'Exception': 'Input greater than 3.14159 '}
# .10 samples completed in 0.00032 minutes
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-8.json
# .....{'Exception': 'Input greater than 3.14159 '}
# {'Exception': 'Input greater than 3.14159 '}
# .{'Exception': 'Input greater than 3.14159 '}
# ...{'Exception': 'Input greater than 3.14159 '}
# {'Exception': 'Input greater than 3.14159 '}
# .10 samples completed in 0.00035 minutes
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-9.json
# .......{'Exception': 'Input greater than 3.14159 '}
# ...10 samples completed in 0.00030 minutes
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-10.json
# ...{'Exception': 'Input greater than 3.14159 '}
# .......{'Exception': 'Input greater than 3.14159 '}
# 10 samples completed in 0.00031 minutes
# {'Exception': 'Input greater than 3.14159 '}
# Samples written to:
#  /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpf9cze250/sampler-2020-02-11-11.json
# ....{'Exception': 'Input greater than 3.14159 '}
# ...{'Exception': 'Input greater than 3.14159 '}
# ..{'Exception': 'Input greater than 3.14159 '}
# {'Exception': 'Input greater than 3.14159 '}

# %% [markdown]
# # Class method

# %%
import yaml

# Make a proper input file. 
YAML="""
xopt: {output_path: temp, verbose: true, algorithm: cnsga}

algorithm:
  name: random_sampler
  options:
    verbose: T
    
simulation: 
  name: test_TNK
  evaluate: xopt.evaluators.test_TNK.evaluate_TNK  
  
vocs:
  name: TNK_test
  description: null
  simulation: test_TNK
  templates: null
  variables:
    x1: [0, 3.14159]
    x2: [0, 3.14159]
  objectives: {y1: MINIMIZE, y2: MINIMIZE}
  constraints:
    c1: [GREATER_THAN, 0]
    c2: [GREATER_THAN, 0]
  linked_variables: {x9: x1}
  constants: {a: dummy_constant}

"""
config = yaml.safe_load(YAML)
config
# Out:
# {'xopt': {'output_path': 'temp', 'verbose': True, 'algorithm': 'cnsga'},
#  'algorithm': {'name': 'random_sampler', 'options': {'verbose': 'T'}},
#  'simulation': {'name': 'test_TNK',
#   'evaluate': 'xopt.evaluators.test_TNK.evaluate_TNK'},
#  'vocs': {'name': 'TNK_test',
#   'description': None,
#   'simulation': 'test_TNK',
#   'templates': None,
#   'variables': {'x1': [0, 3.14159], 'x2': [0, 3.14159]},
#   'objectives': {'y1': 'MINIMIZE', 'y2': 'MINIMIZE'},
#   'constraints': {'c1': ['GREATER_THAN', 0], 'c2': ['GREATER_THAN', 0]},
#   'linked_variables': {'x9': 'x1'},
#   'constants': {'a': 'dummy_constant'}}}

# %%
from xopt import Xopt
from xopt.tools import load_config

# %%
executor = ProcessPoolExecutor()
X = Xopt(YAML)

# %%
X
# Out:
#             Xopt
# ________________________________
#
# Configured: True
#
# Config as YAML:
# xopt: {output_path: /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp, verbose: true,
#   algorithm: cnsga}
# algorithm:
#   name: random_sampler
#   function: xopt.sampler.random_sampler
#   options: {verbose: T, chunk_size: 10, max_samples: 100}
# simulation:
#   name: test_TNK
#   evaluate: xopt.evaluators.test_TNK.evaluate_TNK
#   options: {extra_option: abc}
# vocs:
#   name: TNK_test
#   description: null
#   simulation: test_TNK
#   templates: null
#   variables:
#     x1: [0, 3.14159]
#     x2: [0, 3.14159]
#   objectives: {y1: MINIMIZE, y2: MINIMIZE}
#   constraints:
#     c1: [GREATER_THAN, 0]
#     c2: [GREATER_THAN, 0]
#   linked_variables: {x9: x1}
#   constants: {a: dummy_constant}

# %%
X.run(executor)
# Out:
# ███████╗ █████╗ ███╗   ███╗██████╗ ██╗     ███████╗██████╗
# ██╔════╝██╔══██╗████╗ ████║██╔══██╗██║     ██╔════╝██╔══██╗
# ███████╗███████║██╔████╔██║██████╔╝██║     █████╗  ██████╔╝
# ╚════██║██╔══██║██║╚██╔╝██║██╔═══╝ ██║     ██╔══╝  ██╔══██╗
# ███████║██║  ██║██║ ╚═╝ ██║██║     ███████╗███████╗██║  ██║
# ╚══════╝╚═╝  ╚═╝╚═╝     ╚═╝╚═╝     ╚══════╝╚══════╝╚═╝  ╚═╝
#
#
# Xopt Random Sampler
#
#
# ..........10 samples completed in 0.00031 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-37.json
# ..........10 samples completed in 0.00033 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-38.json
# ..........10 samples completed in 0.00033 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-39.json
# ..........10 samples completed in 0.00039 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-40.json
# ..........10 samples completed in 0.00038 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-41.json
# ..........10 samples completed in 0.00034 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-42.json
# ..........10 samples completed in 0.00031 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-43.json
# ..........10 samples completed in 0.00036 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-44.json
# ..........10 samples completed in 0.00033 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-45.json
# ..........10 samples completed in 0.00037 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-46.json
# ..........10 samples completed in 0.00036 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-47.json
# ..........10 samples completed in 0.00036 minutes
# Samples written to:
#  /Users/chrisonian/Code/GitHub/xopt/examples/sampler/temp/sampler-2020-02-11-48.json

# %%
X.population
# Out:
# {'vocs': {'name': 'TNK_test',
#   'description': None,
#   'simulation': 'test_TNK',
#   'templates': None,
#   'variables': {'x1': [0, 3.14159], 'x2': [0, 3.14159]},
#   'objectives': {'y1': 'MINIMIZE', 'y2': 'MINIMIZE'},
#   'constraints': {'c1': ['GREATER_THAN', 0], 'c2': ['GREATER_THAN', 0]},
#   'linked_variables': {'x9': 'x1'},
#   'constants': {'a': 'dummy_constant'}},
#  'inputs': [{'x1': 1.0889691913962403,
#    'x2': 0.9085420408405658,
#    'a': 'dummy_constant',
#    'x9': 1.0889691913962403},
#   {'x1': 1.9347279476685648,
#    'x2': 1.8158896774967797,
#    'a': 'dummy_constant',
#    'x9': 1.9347279476685648},
#   {'x1': 0.9951838368075004,
#    'x2': 1.18343144488996,
#    'a': 'dummy_constant',
#    'x9': 0.9951838368075004},
#   {'x1': 1.1460085764542967,
#    'x2': 0.12537144154349458,
#    'a': 'dummy_constant',
#    'x9': 1.1460085764542967},
#   {'x1': 0.014913266353671066,
#    'x2': 1.5498504008231713,
#    'a': 'dummy_constant',
#    'x9': 0.014913266353671066},
#   {'x1': 1.0134408285604926,
#    'x2': 0.15631249252620363,
#    'a': 'dummy_constant',
#    'x9': 1.0134408285604926},
#   {'x1': 2.7376486418853516,
#    'x2': 2.188161647751986,
#    'a': 'dummy_constant',
#    'x9': 2.7376486418853516},
#   {'x1': 2.0812159148403517,
#    'x2': 2.7770796152031627,
#    'a': 'dummy_constant',
#    'x9': 2.0812159148403517},
#   {'x1': 0.7211159694306986,
#    'x2': 0.18453925795484766,
#    'a': 'dummy_constant',
#    'x9': 0.7211159694306986},
#   {'x1': 0.5858411305456546,
#    'x2': 1.1973302043421423,
#    'a': 'dummy_constant',
#    'x9': 0.5858411305456546},
#   {'x1': 1.0539291962225972,
#    'x2': 1.0472354844840546,
#    'a': 'dummy_constant',
#    'x9': 1.0539291962225972},
#   {'x1': 2.2510429350960313,
#    'x2': 0.8304421612788804,
#    'a': 'dummy_constant',
#    'x9': 2.2510429350960313},
#   {'x1': 1.6299329635276916,
#    'x2': 1.74572064681339,
#    'a': 'dummy_constant',
#    'x9': 1.6299329635276916},
#   {'x1': 3.001081682621269,
#    'x2': 1.811281700432305,
#    'a': 'dummy_constant',
#    'x9': 3.001081682621269},
#   {'x1': 2.560827628845743,
#    'x2': 2.115238722547328,
#    'a': 'dummy_constant',
#    'x9': 2.560827628845743},
#   {'x1': 2.3065280986590277,
#    'x2': 0.33080713334680184,
#    'a': 'dummy_constant',
#    'x9': 2.3065280986590277},
#   {'x1': 2.439482759047221,
#    'x2': 0.10358821583139553,
#    'a': 'dummy_constant',
#    'x9': 2.439482759047221},
#   {'x1': 1.9876264835434847,
#    'x2': 1.5712837313319463,
#    'a': 'dummy_constant',
#    'x9': 1.9876264835434847},
#   {'x1': 1.3404740943573343,
#    'x2': 2.572159771259082,
#    'a': 'dummy_constant',
#    'x9': 1.3404740943573343},
#   {'x1': 2.586204761967526,
#    'x2': 2.2402270918823173,
#    'a': 'dummy_constant',
#    'x9': 2.586204761967526},
#   {'x1': 1.493983990842588,
#    'x2': 0.6665794033723738,
#    'a': 'dummy_constant',
#    'x9': 1.493983990842588},
#   {'x1': 1.1081507269728286,
#    'x2': 3.0771511916922107,
#    'a': 'dummy_constant',
#    'x9': 1.1081507269728286},
#   {'x1': 2.27294506201269,
#    'x2': 1.140694465596781,
#    'a': 'dummy_constant',
#    'x9': 2.27294506201269},
#   {'x1': 0.5531858536934048,
#    'x2': 2.2009924954270748,
#    'a': 'dummy_constant',
#    'x9': 0.5531858536934048},
#   {'x1': 3.0399280350335407,
#    'x2': 0.9567972873808467,
#    'a': 'dummy_constant',
#    'x9': 3.0399280350335407},
#   {'x1': 2.6695476561978837,
#    'x2': 1.6060644190644748,
#    'a': 'dummy_constant',
#    'x9': 2.6695476561978837},
#   {'x1': 2.6338030231649476,
#    'x2': 0.6965026497844975,
#    'a': 'dummy_constant',
#    'x9': 2.6338030231649476},
#   {'x1': 2.9117220281033522,
#    'x2': 3.1338401310729016,
#    'a': 'dummy_constant',
#    'x9': 2.9117220281033522},
#   {'x1': 0.31965492728354583,
#    'x2': 2.753626561795972,
#    'a': 'dummy_constant',
#    'x9': 0.31965492728354583},
#   {'x1': 1.1923086076478715,
#    'x2': 0.3855204775914914,
#    'a': 'dummy_constant',
#    'x9': 1.1923086076478715},
#   {'x1': 0.8737260333373031,
#    'x2': 1.6957808086860364,
#    'a': 'dummy_constant',
#    'x9': 0.8737260333373031},
#   {'x1': 0.8564914221370094,
#    'x2': 0.47919713155370763,
#    'a': 'dummy_constant',
#    'x9': 0.8564914221370094},
#   {'x1': 2.6986146315639647,
#    'x2': 1.5472436142159078,
#    'a': 'dummy_constant',
#    'x9': 2.6986146315639647},
#   {'x1': 2.118768901615903,
#    'x2': 2.4013839961676164,
#    'a': 'dummy_constant',
#    'x9': 2.118768901615903},
#   {'x1': 1.5267473095873274,
#    'x2': 1.207779390669293,
#    'a': 'dummy_constant',
#    'x9': 1.5267473095873274},
#   {'x1': 0.276891596029507,
#    'x2': 1.0918521655698896,
#    'a': 'dummy_constant',
#    'x9': 0.276891596029507},
#   {'x1': 0.9631752740965608,
#    'x2': 1.0431818099461139,
#    'a': 'dummy_constant',
#    'x9': 0.9631752740965608},
#   {'x1': 1.5501881257292145,
#    'x2': 0.18274329764100286,
#    'a': 'dummy_constant',
#    'x9': 1.5501881257292145},
#   {'x1': 1.8670480716790379,
#    'x2': 1.6521356036766783,
#    'a': 'dummy_constant',
#    'x9': 1.8670480716790379},
#   {'x1': 2.4817065204924345,
#    'x2': 1.1909286562797912,
#    'a': 'dummy_constant',
#    'x9': 2.4817065204924345},
#   {'x1': 0.8685444321672208,
#    'x2': 0.37472147997376887,
#    'a': 'dummy_constant',
#    'x9': 0.8685444321672208},
#   {'x1': 1.3758733543662975,
#    'x2': 0.3996658310748927,
#    'a': 'dummy_constant',
#    'x9': 1.3758733543662975},
#   {'x1': 1.346606376687551,
#    'x2': 0.31185342703716695,
#    'a': 'dummy_constant',
#    'x9': 1.346606376687551},
#   {'x1': 1.7796043070030447,
#    'x2': 2.6000920041942823,
#    'a': 'dummy_constant',
#    'x9': 1.7796043070030447},
#   {'x1': 2.733681989134616,
#    'x2': 0.8784212827860213,
#    'a': 'dummy_constant',
#    'x9': 2.733681989134616},
#   {'x1': 0.9698907330798465,
#    'x2': 0.9958068251865116,
#    'a': 'dummy_constant',
#    'x9': 0.9698907330798465},
#   {'x1': 0.8373088975271985,
#    'x2': 0.7993068679243629,
#    'a': 'dummy_constant',
#    'x9': 0.8373088975271985},
#   {'x1': 0.6691340192299012,
#    'x2': 2.4286589450881193,
#    'a': 'dummy_constant',
#    'x9': 0.6691340192299012},
#   {'x1': 2.5826194959031668,
#    'x2': 2.4178437747100134,
#    'a': 'dummy_constant',
#    'x9': 2.5826194959031668},
#   {'x1': 1.206298799197327,
#    'x2': 1.5249513172919282,
#    'a': 'dummy_constant',
#    'x9': 1.206298799197327},
#   {'x1': 0.4949144274927408,
#    'x2': 2.0438645107692883,
#    'a': 'dummy_constant',
#    'x9': 0.4949144274927408},
#   {'x1': 0.664174689311134,
#    'x2': 1.4060944295554445,
#    'a': 'dummy_constant',
#    'x9': 0.664174689311134},
#   {'x1': 2.687068694766005,
#    'x2': 1.3028325384044557,
#    'a': 'dummy_constant',
#    'x9': 2.687068694766005},
#   {'x1': 1.6171501878987755,
#    'x2': 0.6923461183668577,
#    'a': 'dummy_constant',
#    'x9': 1.6171501878987755},
#   {'x1': 2.704774017677378,
#    'x2': 1.6386188672909694,
#    'a': 'dummy_constant',
#    'x9': 2.704774017677378},
#   {'x1': 1.894536773994976,
#    'x2': 0.6987306467044857,
#    'a': 'dummy_constant',
#    'x9': 1.894536773994976},
#   {'x1': 2.4558898216241536,
#    'x2': 0.4780443096739376,
#    'a': 'dummy_constant',
#    'x9': 2.4558898216241536},
#   {'x1': 1.6779011851768537,
#    'x2': 1.0192504578172308,
#    'a': 'dummy_constant',
#    'x9': 1.6779011851768537},
#   {'x1': 0.46035800810041916,
#    'x2': 0.4263045387939897,
#    'a': 'dummy_constant',
#    'x9': 0.46035800810041916},
#   {'x1': 3.0553708003061226,
#    'x2': 2.6465822647449113,
#    'a': 'dummy_constant',
#    'x9': 3.0553708003061226},
#   {'x1': 1.1811481748939143,
#    'x2': 0.3920160264952963,
#    'a': 'dummy_constant',
#    'x9': 1.1811481748939143},
#   {'x1': 1.6026212496009413,
#    'x2': 2.8913215656503395,
#    'a': 'dummy_constant',
#    'x9': 1.6026212496009413},
#   {'x1': 0.4295046985807418,
#    'x2': 1.4464275355141754,
#    'a': 'dummy_constant',
#    'x9': 0.4295046985807418},
#   {'x1': 2.350674609375215,
#    'x2': 2.903738696842378,
#    'a': 'dummy_constant',
#    'x9': 2.350674609375215},
#   {'x1': 1.5436557334431185,
#    'x2': 2.322972847685869,
#    'a': 'dummy_constant',
#    'x9': 1.5436557334431185},
#   {'x1': 0.14402096211971385,
#    'x2': 1.319430364647826,
#    'a': 'dummy_constant',
#    'x9': 0.14402096211971385},
#   {'x1': 1.1963308856822985,
#    'x2': 1.886637362716656,
#    'a': 'dummy_constant',
#    'x9': 1.1963308856822985},
#   {'x1': 0.529868888328208,
#    'x2': 3.0483166962089996,
#    'a': 'dummy_constant',
#    'x9': 0.529868888328208},
#   {'x1': 1.8373548748241189,
#    'x2': 0.6076869281802548,
#    'a': 'dummy_constant',
#    'x9': 1.8373548748241189},
#   {'x1': 0.6896992698751042,
#    'x2': 2.933579865724641,
#    'a': 'dummy_constant',
#    'x9': 0.6896992698751042},
#   {'x1': 1.3214195597026872,
#    'x2': 0.8101959905051679,
#    'a': 'dummy_constant',
#    'x9': 1.3214195597026872},
#   {'x1': 1.0916699389316096,
#    'x2': 0.7111766600099801,
#    'a': 'dummy_constant',
#    'x9': 1.0916699389316096},
#   {'x1': 2.2115214920164905,
#    'x2': 0.4125202155073446,
#    'a': 'dummy_constant',
#    'x9': 2.2115214920164905},
#   {'x1': 3.034323318961859,
#    'x2': 1.260667052839306,
#    'a': 'dummy_constant',
#    'x9': 3.034323318961859},
#   {'x1': 2.2023438831392843,
#    'x2': 2.3328385632033917,
#    'a': 'dummy_constant',
#    'x9': 2.2023438831392843},
#   {'x1': 3.1025132131338675,
#    'x2': 1.2697847639220898,
#    'a': 'dummy_constant',
#    'x9': 3.1025132131338675},
#   {'x1': 0.5969532613562115,
#    'x2': 3.0736298827111876,
#    'a': 'dummy_constant',
#    'x9': 0.5969532613562115},
#   {'x1': 2.0704242825319508,
#    'x2': 1.8712746823210407,
#    'a': 'dummy_constant',
#    'x9': 2.0704242825319508},
#   {'x1': 2.5213622264401248,
#    'x2': 1.6587129170494725,
#    'a': 'dummy_constant',
#    'x9': 2.5213622264401248},
#   {'x1': 1.3310321848922455,
#    'x2': 2.9721448141105804,
#    'a': 'dummy_constant',
#    'x9': 1.3310321848922455},
#   {'x1': 1.0404218024923766,
#    'x2': 0.9849637061212096,
#    'a': 'dummy_constant',
#    'x9': 1.0404218024923766},
#   {'x1': 2.292068838814263,
#    'x2': 1.1203982338247007,
#    'a': 'dummy_constant',
#    'x9': 2.292068838814263},
#   {'x1': 0.45577801423092107,
#    'x2': 1.2173158250015892,
#    'a': 'dummy_constant',
#    'x9': 0.45577801423092107},
#   {'x1': 0.5409255689496233,
#    'x2': 3.081123354634786,
#    'a': 'dummy_constant',
#    'x9': 0.5409255689496233},
#   {'x1': 2.142322559860862,
#    'x2': 0.19968363067741704,
#    'a': 'dummy_constant',
#    'x9': 2.142322559860862},
#   {'x1': 0.27296182338579933,
#    'x2': 0.4412623893316033,
#    'a': 'dummy_constant',
#    'x9': 0.27296182338579933},
#   {'x1': 2.707281011666406,
#    'x2': 0.1652926506571498,
#    'a': 'dummy_constant',
#    'x9': 2.707281011666406},
#   {'x1': 0.8960846719651909,
#    'x2': 0.9123476195250869,
#    'a': 'dummy_constant',
#    'x9': 0.8960846719651909},
#   {'x1': 0.2986014532590195,
#    'x2': 2.52066840448973,
#    'a': 'dummy_constant',
#    'x9': 0.2986014532590195},
#   {'x1': 2.6486430431625285,
#    'x2': 2.076790286914584,
#    'a': 'dummy_constant',
#    'x9': 2.6486430431625285},
#   {'x1': 1.0811979242772798,
#    'x2': 2.7049252711361196,
#    'a': 'dummy_constant',
#    'x9': 1.0811979242772798},
#   {'x1': 0.9807049644050512,
#    'x2': 0.7070279253432139,
#    'a': 'dummy_constant',
#    'x9': 0.9807049644050512},
#   {'x1': 0.418780585072134,
#    'x2': 2.488368053559871,
#    'a': 'dummy_constant',
#    'x9': 0.418780585072134},
#   {'x1': 1.498198634993161,
#    'x2': 1.370347676434605,
#    'a': 'dummy_constant',
#    'x9': 1.498198634993161},
#   {'x1': 0.601745853439999,
#    'x2': 0.2810450927384284,
#    'a': 'dummy_constant',
#    'x9': 0.601745853439999},
#   {'x1': 0.9738920044512439,
#    'x2': 0.6378417541773184,
#    'a': 'dummy_constant',
#    'x9': 0.9738920044512439},
#   {'x1': 0.17215154079120096,
#    'x2': 0.6772591107973795,
#    'a': 'dummy_constant',
#    'x9': 0.17215154079120096},
#   {'x1': 1.4313509026064266,
#    'x2': 1.895358402812386,
#    'a': 'dummy_constant',
#    'x9': 1.4313509026064266},
#   {'x1': 1.1610933737467894,
#    'x2': 3.040068505190903,
#    'a': 'dummy_constant',
#    'x9': 1.1610933737467894},
#   {'x1': 2.3029159139484445,
#    'x2': 2.788400175752808,
#    'a': 'dummy_constant',
#    'x9': 2.3029159139484445},
#   {'x1': 1.6955271626353838,
#    'x2': 0.30552991813684927,
#    'a': 'dummy_constant',
#    'x9': 1.6955271626353838},
#   {'x1': 2.638020539860883,
#    'x2': 0.27688408803043585,
#    'a': 'dummy_constant',
#    'x9': 2.638020539860883},
#   {'x1': 0.4278030928923982,
#    'x2': 0.6671305271528593,
#    'a': 'dummy_constant',
#    'x9': 0.4278030928923982},
#   {'x1': 0.547888777848131,
#    'x2': 0.3277038923131322,
#    'a': 'dummy_constant',
#    'x9': 0.547888777848131},
#   {'x1': 0.48206466780299123,
#    'x2': 1.009598534746227,
#    'a': 'dummy_constant',
#    'x9': 0.48206466780299123},
#   {'x1': 0.5445616181728716,
#    'x2': 3.109393773616258,
#    'a': 'dummy_constant',
#    'x9': 0.5445616181728716},
#   {'x1': 2.7301034309649324,
#    'x2': 0.9799979759350904,
#    'a': 'dummy_constant',
#    'x9': 2.7301034309649324},
#   {'x1': 1.6829226556650092,
#    'x2': 0.34213759458835924,
#    'a': 'dummy_constant',
#    'x9': 1.6829226556650092},
#   {'x1': 1.7095332680431892,
#    'x2': 2.2782339296901593,
#    'a': 'dummy_constant',
#    'x9': 1.7095332680431892},
#   {'x1': 2.106493625938386,
#    'x2': 1.1646982110729363,
#    'a': 'dummy_constant',
#    'x9': 2.106493625938386},
#   {'x1': 0.9249913378419325,
#    'x2': 2.821429578344148,
#    'a': 'dummy_constant',
#    'x9': 0.9249913378419325},
#   {'x1': 0.6579929081107669,
#    'x2': 2.446332204007417,
#    'a': 'dummy_constant',
#    'x9': 0.6579929081107669},
#   {'x1': 1.4794450091288287,
#    'x2': 0.5257614479931115,
#    'a': 'dummy_constant',
#    'x9': 1.4794450091288287},
#   {'x1': 1.6448562468723666,
#    'x2': 1.5739518637750887,
#    'a': 'dummy_constant',
#    'x9': 1.6448562468723666},
#   {'x1': 1.1921148382037983,
#    'x2': 0.6515854235093929,
#    'a': 'dummy_constant',
#    'x9': 1.1921148382037983},
#   {'x1': 0.5820957398732923,
#    'x2': 0.2352282401874782,
#    'a': 'dummy_constant',
#    'x9': 0.5820957398732923},
#   {'x1': 0.18746796756408426,
#    'x2': 0.7003032093431114,
#    'a': 'dummy_constant',
#    'x9': 0.18746796756408426},
#   {'x1': 1.6685378599931926,
#    'x2': 1.662635351596891,
#    'a': 'dummy_constant',
#    'x9': 1.6685378599931926},
#   {'x1': 2.359800577050598,
#    'x2': 2.4650300679310195,
#    'a': 'dummy_constant',
#    'x9': 2.359800577050598},
#   {'x1': 2.688789807903487,
#    'x2': 1.7888892197631068,
#    'a': 'dummy_constant',
#    'x9': 2.688789807903487}],
#  'outputs': [{'y1': 1.0889691913962403,
#    'y2': 0.9085420408405658,
#    'c1': 0.9983894995275125,
#    'c2': -0.013791307548115611},
#   {'y1': 1.9347279476685648,
#    'y2': 1.8158896774967797,
#    'c1': 5.953196858216406,
#    'c2': -3.2900099271638306},
#   {'y1': 0.9951838368075004,
#    'y2': 1.18343144488996,
#    'c1': 1.3718470983612916,
#    'c2': -0.21228557209977578},
#   {'y1': 1.1460085764542967,
#    'y2': 0.12537144154349458,
#    'c1': 0.3462324283615769,
#    'c2': -0.05767363766370617},
#   {'y1': 0.014913266353671066,
#    'y2': 1.5498504008231713,
#    'c1': 1.3034414156342615,
#    'c2': -0.8374950032682378},
#   {'y1': 1.0134408285604926,
#    'y2': 0.15631249252620363,
#    'c1': 0.1284255283693262,
#    'c2': 0.11825741277356401},
#   {'y1': 2.7376486418853516,
#    'y2': 2.188161647751986,
#    'c1': 11.303294287916307,
#    'c2': -7.356961193472058},
#   {'y1': 2.0812159148403517,
#    'y2': 2.7770796152031627,
#    'c1': 11.108467381405918,
#    'c2': -7.185335343318195},
#   {'y1': 0.7211159694306986,
#    'y2': 0.18453925795484766,
#    'c1': -0.38121828680945136,
#    'c2': 0.35159224829104424},
#   {'y1': 0.5858411305456546,
#    'y2': 1.1973302043421423,
#    'c1': 0.7225686772533172,
#    'c2': 0.006361886418789875},
#   {'y1': 1.0539291962225972,
#    'y2': 1.0472354844840546,
#    'c1': 1.1075987859924392,
#    'c2': -0.1063042299063105},
#   {'y1': 2.2510429350960313,
#    'y2': 0.8304421612788804,
#    'c1': 4.675930979685463,
#    'c2': -2.6753433825003814},
#   {'y1': 1.6299329635276916,
#    'y2': 1.74572064681339,
#    'c1': 4.6188963942112515,
#    'c2': -2.328568431963642},
#   {'y1': 3.001081682621269,
#    'y2': 1.811281700432305,
#    'c1': 11.361318473219596,
#    'c2': -7.474869281032275},
#   {'y1': 2.560827628845743,
#    'y2': 2.115238722547328,
#    'c1': 10.027002789948275,
#    'c2': -6.356006646630291},
#   {'y1': 2.3065280986590277,
#    'y2': 0.33080713334680184,
#    'c1': 4.494568292052533,
#    'c2': -2.792169997370929},
#   {'y1': 2.439482759047221,
#    'y2': 0.10358821583139553,
#    'c1': 4.883986732595249,
#    'c2': -3.418735675269157},
#   {'y1': 1.9876264835434847,
#    'y2': 1.5712837313319463,
#    'c1': 5.448427311678663,
#    'c2': -2.8606813875564514},
#   {'y1': 1.3404740943573343,
#    'y2': 2.572159771259082,
#    'c1': 7.396231498344602,
#    'c2': -4.500242820910272},
#   {'y1': 2.586204761967526,
#    'y2': 2.2402270918823173,
#    'c1': 10.665766476240579,
#    'c2': -6.880640640177169},
#   {'y1': 1.493983990842588,
#    'y2': 0.6665794033723738,
#    'c1': 1.585483183274737,
#    'c2': -0.5157528716792541},
#   {'y1': 1.1081507269728286,
#    'y2': 3.0771511916922107,
#    'c1': 9.623863613368803,
#    'c2': -6.511555571558162},
#   {'y1': 2.27294506201269,
#    'y2': 1.140694465596781,
#    'c1': 5.427431496244278,
#    'c2': -3.0538235911615264},
#   {'y1': 0.5531858536934048,
#    'y2': 2.2009924954270748,
#    'c1': 4.220185165037773,
#    'c2': -2.396204204532323},
#   {'y1': 3.0399280350335407,
#    'y2': 0.9567972873808467,
#    'c1': 9.140055364155353,
#    'c2': -6.159898184907843},
#   {'y1': 2.6695476561978837,
#    'y2': 1.6060644190644748,
#    'c1': 8.778482014866952,
#    'c2': -5.4303155316341645},
#   {'y1': 2.6338030231649476,
#    'y2': 0.6965026497844975,
#    'c1': 6.476494818975217,
#    'c2': -4.091728633040199},
#   {'y1': 2.9117220281033522,
#    'y2': 3.1338401310729016,
#    'c1': 17.215851042887703,
#    'c2': -12.253516976889067},
#   {'y1': 0.31965492728354583,
#    'y2': 2.753626561795972,
#    'c1': 6.712109551587921,
#    'c2': -4.611357025285438},
#   {'y1': 1.1923086076478715,
#    'y2': 0.3855204775914914,
#    'c1': 0.541508005542564,
#    'c2': 0.007603230725785287},
#   {'y1': 0.8737260333373031,
#    'y2': 1.6957808086860364,
#    'c1': 2.615124715473072,
#    'c2': -1.0695628904158663},
#   {'y1': 0.8564914221370094,
#    'y2': 0.47919713155370763,
#    'c1': -0.0065153002432598445,
#    'c2': 0.37248110660713885},
#   {'y1': 2.6986146315639647,
#    'y2': 1.5472436142159078,
#    'c1': 8.722260326526238,
#    'c2': -5.430625485643146},
#   {'y1': 2.118768901615903,
#    'y2': 2.4013839961676164,
#    'c1': 9.201718550558251,
#    'c2': -5.735673857721091},
#   {'y1': 1.5267473095873274,
#    'y2': 1.207779390669293,
#    'c1': 2.8180077466762725,
#    'c2': -1.0551617036010108},
#   {'y1': 0.276891596029507,
#    'y2': 1.0918521655698896,
#    'c1': 0.3361349877030758,
#    'c2': 0.09993365418797129},
#   {'y1': 0.9631752740965608,
#    'y2': 1.0431818099461139,
#    'c1': 0.9355873714873768,
#    'c2': -0.009577813190760343},
#   {'y1': 1.5501881257292145,
#    'y2': 0.18274329764100286,
#    'c1': 1.4666690185072442,
#    'c2': -0.7035469146143458},
#   {'y1': 1.8670480716790379,
#    'y2': 1.6521356036766783,
#    'c1': 5.159377395554566,
#    'c2': -2.6962368795408},
#   {'y1': 2.4817065204924345,
#    'y2': 1.1909286562797912,
#    'c1': 6.51312563130542,
#    'c2': -3.9045431414308296},
#   {'y1': 0.8685444321672208,
#    'y2': 0.37472147997376887,
#    'c1': -0.20249446487447637,
#    'c2': 0.34848029393857805},
#   {'y1': 1.3758733543662975,
#    'y2': 0.3996658310748927,
#    'c1': 1.071564049315061,
#    'c2': -0.2772210783427618},
#   {'y1': 1.346606376687551,
#    'y2': 0.31185342703716695,
#    'c1': 0.9983799450237001,
#    'c2': -0.25214148996568203},
#   {'y1': 1.7796043070030447,
#    'y2': 2.6000920041942823,
#    'c1': 9.025880769099173,
#    'c2': -5.547773608581499},
#   {'y1': 2.733681989134616,
#    'y2': 0.8784212827860213,
#    'c1': 7.218721296465047,
#    'c2': -4.632537895849792},
#   {'y1': 0.9698907330798465,
#    'y2': 0.9958068251865116,
#    'c1': 0.8345356992125085,
#    'c2': 0.03337829106415627},
#   {'y1': 0.8373088975271985,
#    'y2': 0.7993068679243629,
#    'c1': 0.24679750781645576,
#    'c2': 0.29663810646229394},
#   {'y1': 0.6691340192299012,
#    'y2': 2.4286589450881193,
#    'c1': 5.386064159343155,
#    'c2': -3.2483316429292777},
#   {'y1': 2.5826194959031668,
#    'y2': 2.4178437747100134,
#    'c1': 11.429462151181244,
#    'c2': -7.515428708909914},
#   {'y1': 1.206298799197327,
#    'y2': 1.5249513172919282,
#    'c1': 2.8089896774898016,
#    'c2': -1.049383196566045},
#   {'y1': 0.4949144274927408,
#    'y2': 2.0438645107692883,
#    'c1': 3.5013472027823274,
#    'c2': -1.8835434906606205},
#   {'y1': 0.664174689311134,
#    'y2': 1.4060944295554445,
#    'c1': 1.3469565545293516,
#    'c2': -0.34796044388181374},
#   {'y1': 2.687068694766005,
#    'y2': 1.3028325384044557,
#    'c1': 7.858741592642974,
#    'c2': -4.927809560346419},
#   {'y1': 1.6171501878987755,
#    'y2': 0.6923461183668577,
#    'c1': 1.9963000965051856,
#    'c2': -0.7850215715730665},
#   {'y1': 2.704774017677378,
#    'y2': 1.6386188672909694,
#    'c1': 9.076728955605638,
#    'c2': -5.657481393976217},
#   {'y1': 1.894536773994976,
#    'y2': 0.6987306467044857,
#    'c1': 2.9966802655772433,
#    'c2': -1.484226683963898},
#   {'y1': 2.4558898216241536,
#    'y2': 0.4780443096739376,
#    'c1': 5.359705944127556,
#    'c2': -3.3259870466706576},
#   {'y1': 1.6779011851768537,
#    'y2': 1.0192504578172308,
#    'c1': 2.9313076321367384,
#    'c2': -1.1570722399844402},
#   {'y1': 0.46035800810041916,
#    'y2': 0.4263045387939897,
#    'c1': -0.6880584384312592,
#    'c2': 0.49299749147586697},
#   {'y1': 3.0553708003061226,
#    'y2': 2.6465822647449113,
#    'c1': 15.298395119391543,
#    'c2': -10.637735346374546},
#   {'y1': 1.1811481748939143,
#    'y2': 0.3920160264952963,
#    'c1': 0.5084791103910405,
#    'c2': 0.024376625304824942},
#   {'y1': 1.6026212496009413,
#    'y2': 2.8913215656503395,
#    'c1': 9.952300975810806,
#    'c2': -6.4341924504159325},
#   {'y1': 0.4295046985807418,
#    'y2': 1.4464275355141754,
#    'c1': 1.2860140569096647,
#    'c2': -0.4006946675016277},
#   {'y1': 2.350674609375215,
#    'y2': 2.903738696842378,
#    'c1': 12.96806287069311,
#    'c2': -8.702956232483599},
#   {'y1': 1.5436557334431185,
#    'y2': 2.322972847685869,
#    'c1': 6.878993598144739,
#    'c2': -3.9124472933486203},
#   {'y1': 0.14402096211971385,
#    'y2': 1.319430364647826,
#    'c1': 0.7784364096538855,
#    'c2': -0.2981871979170433},
#   {'y1': 1.1963308856822985,
#    'y2': 1.886637362716656,
#    'c1': 4.083369238481798,
#    'c2': -1.907639878036897},
#   {'y1': 0.529868888328208,
#    'y2': 3.0483166962089996,
#    'c1': 8.665565079088347,
#    'c2': -5.994810134667514},
#   {'y1': 1.8373548748241189,
#    'y2': 0.6076869281802548,
#    'c1': 2.706375909162891,
#    'c2': -1.300114535716734},
#   {'y1': 0.6896992698751042,
#    'y2': 2.933579865724641,
#    'c1': 8.166671666407652,
#    'c2': -5.458296775851508},
#   {'y1': 1.3214195597026872,
#    'y2': 0.8101959905051679,
#    'c1': 1.4836902741479054,
#    'c2': -0.2709516455876387},
#   {'y1': 1.0916699389316096,
#    'y2': 0.7111766600099801,
#    'c1': 0.7957834451291945,
#    'c2': 0.10533110163169467},
#   {'y1': 2.2115214920164905,
#    'y2': 0.4125202155073446,
#    'c1': 4.1591820063547384,
#    'c2': -2.4369585303292354},
#   {'y1': 3.034323318961859,
#    'y2': 1.260667052839306,
#    'c1': 9.69641410510316,
#    'c2': -6.501409050309087},
#   {'y1': 2.2023438831392843,
#    'y2': 2.3328385632033917,
#    'c1': 9.202860401217603,
#    'c2': -5.757271895227211},
#   {'y1': 3.1025132131338675,
#    'y2': 1.2697847639220898,
#    'c1': 10.138169624715422,
#    'c2': -6.865643607302955},
#   {'y1': 0.5969532613562115,
#    'y2': 3.0736298827111876,
#    'c1': 8.903292452680379,
#    'c2': -6.132970708071607},
#   {'y1': 2.0704242825319508,
#    'y2': 1.8712746823210407,
#    'c1': 6.719208963951696,
#    'c2': -3.846626681540663},
#   {'y1': 2.5213622264401248,
#    'y2': 1.6587129170494725,
#    'c1': 8.207939602439515,
#    'c2': -4.928520874616276},
#   {'y1': 1.3310321848922455,
#    'y2': 2.9721448141105804,
#    'c1': 9.515406353171729,
#    'c2': -6.302114474260615},
#   {'y1': 1.0404218024923766,
#    'y2': 0.9849637061212096,
#    'c1': 0.9620706265817192,
#    'c2': -0.027245520863928285},
#   {'y1': 2.292068838814263,
#    'y2': 1.1203982338247007,
#    'c1': 5.454117557837724,
#    'c2': -3.096404691581909},
#   {'y1': 0.45577801423092107,
#    'y2': 1.2173158250015892,
#    'c1': 0.6043965172185547,
#    'c2': -0.016497576823071125},
#   {'y1': 0.5409255689496233,
#    'y2': 3.081123354634786,
#    'c1': 8.879477730521053,
#    'c2': -6.163872674034981},
#   {'y1': 2.142322559860862,
#    'y2': 0.19968363067741704,
#    'c1': 3.6210543218865383,
#    'c2': -2.287413312311033},
#   {'y1': 0.27296182338579933,
#    'y2': 0.4412623893316033,
#    'c1': -0.6461132653225596,
#    'c2': 0.44500355945266684},
#   {'y1': 2.707281011666406,
#    'y2': 0.1652926506571498,
#    'c1': 6.300630514871397,
#    'c2': -4.48411847416719},
#   {'y1': 0.8960846719651909,
#    'y2': 0.9123476195250869,
#    'c1': 0.5363792295726372,
#    'c2': 0.17308637330622126},
#   {'y1': 0.2986014532590195,
#    'y2': 2.52066840448973,
#    'c1': 5.473988888591394,
#    'c2': -3.623662175532449},
#   {'y1': 2.6486430431625285,
#    'y2': 2.076790286914584,
#    'c1': 10.363228977305313,
#    'c2': -6.602934535838908},
#   {'y1': 1.0811979242772798,
#    'y2': 2.7049252711361196,
#    'c1': 7.387583617797121,
#    'c2': -4.699486478478909},
#   {'y1': 0.9807049644050512,
#    'y2': 0.7070279253432139,
#    'c1': 0.5458891090439714,
#    'c2': 0.2260621753244232},
#   {'y1': 0.418780585072134,
#    'y2': 2.488368053559871,
#    'c1': 5.456333776964965,
#    'c2': -3.4602041097786955},
#   {'y1': 1.498198634993161,
#    'y2': 1.370347676434605,
#    'c1': 3.0467885566957547,
#    'c2': -1.253905592777326},
#   {'y1': 0.601745853439999,
#    'y2': 0.2810450927384284,
#    'c1': -0.6348899013327017,
#    'c2': 0.44170652989384285},
#   {'y1': 0.9738920044512439,
#    'y2': 0.6378417541773184,
#    'c1': 0.45422446816541384,
#    'c2': 0.256426018922502},
#   {'y1': 0.17215154079120096,
#    'y2': 0.6772591107973795,
#    'c1': -0.4450180335183811,
#    'c2': 0.36109459543373873},
#   {'y1': 1.4313509026064266,
#    'y2': 1.895358402812386,
#    'c1': 4.701394035141852,
#    'c2': -2.3144395760849386},
#   {'y1': 1.1610933737467894,
#    'y2': 3.040068505190903,
#    'c1': 9.499930619951877,
#    'c2': -6.388992459874661},
#   {'y1': 2.3029159139484445,
#    'y2': 2.788400175752808,
#    'c1': 12.073628321153732,
#    'c2': -7.9872811571540385},
#   {'y1': 1.6955271626353838,
#    'y2': 0.30552991813684927,
#    'c1': 2.0640125869990547,
#    'c2': -0.967103809338872},
#   {'y1': 2.638020539860883,
#    'y2': 0.27688408803043585,
#    'c1': 6.046041457861259,
#    'c2': -4.120912539041033},
#   {'y1': 0.4278030928923982,
#    'y2': 0.6671305271528593,
#    'c1': -0.27643188212377345,
#    'c2': 0.4668549934977037},
#   {'y1': 0.547888777848131,
#    'y2': 0.3277038923131322,
#    'c1': -0.5227708503803409,
#    'c2': 0.4680207162321676},
#   {'y1': 0.48206466780299123,
#    'y2': 1.009598534746227,
#    'c1': 0.1852539914832072,
#    'c2': 0.2399876572434813},
#   {'y1': 0.5445616181728716,
#    'y2': 3.109393773616258,
#    'c1': 9.058197093237409,
#    'c2': -6.31092160360148},
#   {'y1': 2.7301034309649324,
#    'y2': 0.9799979759350904,
#    'c1': 7.342002324358966,
#    'c2': -4.703759369703347},
#   {'y1': 1.6829226556650092,
#    'y2': 0.34213759458835924,
#    'c1': 2.049059289301794,
#    'c2': -0.9242265483279073},
#   {'y1': 1.7095332680431892,
#    'y2': 2.2782339296901593,
#    'c1': 7.176946246879618,
#    'c2': -4.125086635204544},
#   {'y1': 2.106493625938386,
#    'y2': 1.1646982110729363,
#    'c1': 4.816361766767028,
#    'c2': -2.5226454819842243},
#   {'y1': 0.9249913378419325,
#    'y2': 2.821429578344148,
#    'c1': 7.781178230222375,
#    'c2': -5.0696529244517645},
#   {'y1': 0.6579929081107669,
#    'y2': 2.446332204007417,
#    'c1': 5.466169220553777,
#    'c2': -3.3131708073696675},
#   {'y1': 1.4794450091288287,
#    'y2': 0.5257614479931115,
#    'c1': 1.3969507873554379,
#    'c2': -0.4599761781100732},
#   {'y1': 1.6448562468723666,
#    'y2': 1.5739518637750887,
#    'c1': 4.089021608697111,
#    'c2': -1.9640684317086679},
#   {'y1': 1.1921148382037983,
#    'y2': 0.6515854235093929,
#    'c1': 0.8605888301486956,
#    'c2': -0.0020010898823918273},
#   {'y1': 0.5820957398732923,
#    'y2': 0.2352282401874782,
#    'c1': -0.7048741965768823,
#    'c2': 0.423156204700437},
#   {'y1': 0.18746796756408426,
#    'y2': 0.7003032093431114,
#    'c1': -0.42410344348459755,
#    'c2': 0.3622023530283254},
#   {'y1': 1.6685378599931926,
#    'y2': 1.662635351596891,
#    'c1': 4.448415087128827,
#    'c2': -2.2172016910202963},
#   {'y1': 2.359800577050598,
#    'y2': 2.4650300679310195,
#    'c1': 10.551057218797082,
#    'c2': -6.820201354270724},
#   {'y1': 2.688789807903487,
#    'y2': 1.7888892197631068,
#    'c1': 9.529664935583861,
#    'c2': -5.952036244003734}],
#  'error': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False]}

# %%
# !rm -r temp
