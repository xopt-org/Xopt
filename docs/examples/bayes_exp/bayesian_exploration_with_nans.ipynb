# %% [markdown]
# # Bayesian Exploration with NaNs
#
# As violations of constraints can lead to invalid values of the objective, the evaluate function may simply return NaNs. We demonstrate below how we can still perform Bayesian Exploration in that case.

# %%
# set values if testing
import os
SMOKE_TEST = os.environ.get("SMOKE_TEST")
NUM_MC_SAMPLES = 1 if SMOKE_TEST else 128

# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import torch
import yaml
from copy import deepcopy
from xopt import Xopt, Evaluator
from xopt.generators.bayesian import BayesianExplorationGenerator
from xopt.resources.test_functions.tnk import evaluate_TNK, tnk_vocs

vocs = deepcopy(tnk_vocs)

# can only explore one objective
del vocs.objectives["y2"]

# %%
# modify the evaluate function to return NaNs if constraints are violated
def evaluate(input_dict):
    output_dict = evaluate_TNK(input_dict)
    del output_dict["y2"]
    for c in vocs.constraints.keys():
        if vocs.constraints[c][0].upper() == "GREATER_THAN" and output_dict[c] <= vocs.constraints[c][1]:
            output_dict["y1"] = torch.nan
        elif vocs.constraints[c][0].upper() == "LESS_THAN" and output_dict[c] >= vocs.constraints[c][1]:
            output_dict["y1"] = torch.nan
    return output_dict

# %%
generator_options = BayesianExplorationGenerator.default_options()
generator_options.optim.max_travel_distances = [0.25, 0.25]
generator_options.acq.monte_carlo_samples = NUM_MC_SAMPLES

evaluator = Evaluator(function=evaluate)
generator = BayesianExplorationGenerator(vocs, generator_options)

print(yaml.dump(generator.options.dict()))
# Out:
# acq:
#   monte_carlo_samples: 128
#   proximal_lengthscales: null
#   use_transformed_proximal_weights: true
# model:
#   covar_modules: {}
#   custom_constructor: null
#   mean_modules: {}
#   name: standard
#   use_low_noise_prior: true
# n_initial: 3
# optim:
#   max_travel_distances:
#   - 0.25
#   - 0.25
#   num_restarts: 20
#   raw_samples: 20
#   sequential: true
#   use_turbo: false
# use_cuda: false

# %% [markdown]
# ## Run exploration
# We start with evaluating 2 points that we know satisfy the constraints. We then run
# 30 exploration steps.

# %%
X = Xopt(generator=generator, evaluator=evaluator, vocs=vocs)
X.evaluate_data(pd.DataFrame({"x1": [1.0, 0.75], "x2": [0.7, 0.95]}))
# Out:
#      x1    x2    y1        c1     c2 some_array  xopt_runtime  xopt_error
# 1  1.00  0.70  1.00  0.584045  0.290  [1, 2, 3]      0.000031       False
# 2  0.75  0.95  0.75  0.494833  0.265  [1, 2, 3]      0.000009       False

# %%
for i in range(30):
    print(f"step {i}")
    X.step()
# Out:
# step 0
# step 1
# step 2
# step 3
# step 4
# step 5
# step 6
# step 7
# step 8
# step 9
# step 10
# step 11
# step 12
# step 13
# step 14
# step 15
# step 16
# step 17
# step 18
# step 19
# step 20
# step 21
# step 22
# step 23
# step 24
# step 25
# step 26
# step 27
# step 28
# step 29

# %%
# view the data
X.data
# Out:
#           x1        x2        y1        c1        c2 some_array  xopt_runtime  \
# 1   1.000000  0.700000  1.000000  0.584045  0.290000  [1, 2, 3]      0.000031
# 2   0.750000  0.950000  0.750000  0.494833  0.265000  [1, 2, 3]      0.000009
# 3   1.535397  1.735397       NaN  4.313110  2.598255  [1, 2, 3]      0.000033
# 4   1.508647  1.341682       NaN  3.016839  1.725798  [1, 2, 3]      0.000021
# 5   0.928705  0.880895  0.928705  0.547268  0.328869  [1, 2, 3]      0.000017
# 6   0.170154  0.953644  0.170154  0.033421  0.314592  [1, 2, 3]      0.000032
# 7   0.510543  0.179021       NaN -0.770458  0.103139  [1, 2, 3]      0.000020
# 8   0.867468  0.516951  0.867468  0.087520  0.135320  [1, 2, 3]      0.000020
# 9   0.411726  1.058588  0.411726  0.196129  0.319813  [1, 2, 3]      0.000020
# 10  1.114446  0.434078  1.114446  0.336151  0.381889  [1, 2, 3]      0.000019
# 11  0.573727  0.879337  0.573727  0.200864  0.149332  [1, 2, 3]      0.000017
# 12  1.113326  0.748012  1.113326  0.898933  0.437678  [1, 2, 3]      0.000016
# 13  0.626544  1.138549  0.626544  0.708249  0.423759  [1, 2, 3]      0.000018
# 14  0.380951  1.165148  0.380951  0.469007  0.456595  [1, 2, 3]      0.000021
# 15  0.910498  1.033446  0.910498  0.843880  0.453072  [1, 2, 3]      0.000023
# 16  0.159597  1.084426  0.159597  0.270861  0.457428  [1, 2, 3]      0.000021
# 17  0.014925  0.969460       NaN -0.156907  0.455691  [1, 2, 3]      0.000020
# 18  0.551653  0.812279  0.551653  0.063391  0.100186  [1, 2, 3]      0.000017
# 19  1.169863  0.362567  1.169863  0.490432  0.467604  [1, 2, 3]      0.000021
# 20  1.132766  0.279391  1.132766  0.435902  0.449061  [1, 2, 3]      0.000027
# 21  1.054421  0.148514  1.054421  0.195806  0.430925  [1, 2, 3]      0.000020
# 22  1.165036  0.694423  1.165036  0.907419  0.480073  [1, 2, 3]      0.000017
# 23  0.583190  1.184033  0.583190  0.691377  0.474821  [1, 2, 3]      0.000018
# 24  0.993171  0.444354  0.993171  0.093706  0.246314  [1, 2, 3]      0.000024
# 25  0.256280  1.149024  0.256280  0.479184  0.480632  [1, 2, 3]      0.000018
# 26  0.075188  1.048580  0.075188  0.063896  0.481405  [1, 2, 3]      0.000023
# 27  0.832638  0.524023  0.832638  0.058481  0.111225  [1, 2, 3]      0.000020
# 28  0.817046  1.111873  0.817046  0.979345  0.474907  [1, 2, 3]      0.000037
# 29  1.041750  0.930507  1.041750  0.889043  0.478829  [1, 2, 3]      0.000017
# 30  0.256352  0.983929  0.256352  0.093103  0.293551  [1, 2, 3]      0.000016
# 31  0.720452  0.737586       NaN -0.035154  0.105046  [1, 2, 3]      0.000021
# 32  1.195512  0.495078  1.195512  0.574352  0.483761  [1, 2, 3]      0.000024
#
#     xopt_error               a
# 1        False             NaN
# 2        False             NaN
# 3        False  dummy_constant
# 4        False  dummy_constant
# 5        False  dummy_constant
# 6        False  dummy_constant
# 7        False  dummy_constant
# 8        False  dummy_constant
# 9        False  dummy_constant
# 10       False  dummy_constant
# 11       False  dummy_constant
# 12       False  dummy_constant
# 13       False  dummy_constant
# 14       False  dummy_constant
# 15       False  dummy_constant
# 16       False  dummy_constant
# 17       False  dummy_constant
# 18       False  dummy_constant
# 19       False  dummy_constant
# 20       False  dummy_constant
# 21       False  dummy_constant
# 22       False  dummy_constant
# 23       False  dummy_constant
# 24       False  dummy_constant
# 25       False  dummy_constant
# 26       False  dummy_constant
# 27       False  dummy_constant
# 28       False  dummy_constant
# 29       False  dummy_constant
# 30       False  dummy_constant
# 31       False  dummy_constant
# 32       False  dummy_constant

# %%
# plot results
ax = X.data.plot("x1", "x2")
ax.set_aspect("equal")
