# %% [markdown]
# # Bayesian Exploration with NaNs
#
# As violations of constraints can lead to invalid values of the objective, the evaluate function may simply return NaNs. We demonstrate below how we can still perform Bayesian Exploration in that case.

# %%
# set values if testing
import os
SMOKE_TEST = os.environ.get("SMOKE_TEST")
NUM_MC_SAMPLES = 1 if SMOKE_TEST else 128
NUM_RESTARTS = 1 if SMOKE_TEST else 20

# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import torch
import yaml
from copy import deepcopy
from xopt import Xopt, Evaluator
from xopt.generators.bayesian import BayesianExplorationGenerator
from xopt.resources.test_functions.tnk import evaluate_TNK, tnk_vocs

vocs = deepcopy(tnk_vocs)
vocs.objectives = {}
vocs.observables = ["y1"]

# %%
# modify the evaluate function to return NaNs if constraints are violated
def evaluate(input_dict):
    output_dict = evaluate_TNK(input_dict)
    del output_dict["y2"]
    for c in vocs.constraints.keys():
        if vocs.constraints[c][0].upper() == "GREATER_THAN" and output_dict[c] <= vocs.constraints[c][1]:
            output_dict["y1"] = torch.nan
        elif vocs.constraints[c][0].upper() == "LESS_THAN" and output_dict[c] >= vocs.constraints[c][1]:
            output_dict["y1"] = torch.nan
    return output_dict

# %%
generator = BayesianExplorationGenerator(vocs=vocs)
generator.max_travel_distances = [0.25, 0.25]
generator.n_monte_carlo_samples = NUM_MC_SAMPLES
generator.numerical_optimizer.n_restarts = NUM_RESTARTS

evaluator = Evaluator(function=evaluate)
X = Xopt(generator=generator, evaluator=evaluator, vocs=vocs)
X
# Out:
#             Xopt
# ________________________________
# Version: 1.4.1+32.g980ee23.dirty
# Data size: 0
# Config as YAML:
# xopt: {asynch: false, strict: false, dump_file: null, max_evaluations: null}
# generator:
#   name: bayesian_exploration
#   model: null
#   turbo_controller: null
#   use_cuda: false
#   gp_constructor:
#     name: standard
#     use_low_noise_prior: true
#     covar_modules: {}
#     mean_modules: {}
#     dtype: torch.float64
#     device: cpu
#   numerical_optimizer: {name: LBFGS, n_raw_samples: 20, n_restarts: 20}
#   max_travel_distances: [0.25, 0.25]
#   n_monte_carlo_samples: 128
# evaluator:
#   function: __main__.evaluate
#   max_workers: 1
#   function_kwargs: {}
#   vectorized: false
# vocs:
#   variables:
#     x1: [0.0, 3.14159]
#     x2: [0.0, 3.14159]
#   constraints:
#     c1: [GREATER_THAN, 0.0]
#     c2: [LESS_THAN, 0.5]
#   objectives: {y1: MINIMIZE}
#   constants: {a: dummy_constant}

# %% [markdown]
# ## Run exploration
# We start with evaluating 2 points that we know satisfy the constraints. We then run
# 30 exploration steps.

# %%
X.evaluate_data(pd.DataFrame({"x1": [1.0, 0.75], "x2": [0.7, 0.95]}))
# Out:
#      x1    x2    y1        c1     c2 some_array  xopt_runtime  xopt_error
# 1  1.00  0.70  1.00  0.584045  0.290  [1, 2, 3]      0.000032       False
# 2  0.75  0.95  0.75  0.494833  0.265  [1, 2, 3]      0.000010       False

# %%
N_STEPS = 1 if SMOKE_TEST else 30
for i in range(N_STEPS):
    print(f"step {i}")
    X.step()
# Out:
# step 0
# step 1
# step 2
# step 3
# step 4
# step 5
# step 6
# step 7
# step 8
# step 9
# step 10
# step 11
# step 12
# step 13
# step 14
# step 15
# step 16
# step 17
# step 18
# step 19
# step 20
# step 21
# step 22
# step 23
# step 24
# step 25
# step 26
# step 27
# step 28
# step 29

# %%
# view the data
X.data
# Out:
#           x1        x2        y1        c1        c2 some_array  xopt_runtime  \
# 1   1.000000  0.700000  1.000000  0.584045  0.290000  [1, 2, 3]      0.000032
# 2   0.750000  0.950000  0.750000  0.494833  0.265000  [1, 2, 3]      0.000010
# 3   1.535397  1.735397       NaN  4.313110  2.598255  [1, 2, 3]      0.000027
# 4   0.832569  0.951134  0.832569  0.549112  0.314124  [1, 2, 3]      0.000027
# 5   0.411540  0.952026       NaN -0.021292  0.212153  [1, 2, 3]      0.000028
# 6   0.473753  0.959038  0.473753  0.095137  0.211405  [1, 2, 3]      0.000026
# 7   0.776118  0.637216  0.776118  0.008068  0.095069  [1, 2, 3]      0.000027
# 8   0.982115  0.536761  0.982115  0.267497  0.233786  [1, 2, 3]      0.000036
# 9   1.141206  0.470245  1.141206  0.423526  0.412031  [1, 2, 3]      0.000028
# 10  0.402530  1.102203  0.402530  0.299169  0.372149  [1, 2, 3]      0.000034
# 11  0.278812  1.126397  0.278812  0.420300  0.441297  [1, 2, 3]      0.000027
# 12  0.151618  1.065980  0.151618  0.222938  0.441704  [1, 2, 3]      0.000035
# 13  0.937015  0.990647  0.937015  0.769120  0.431717  [1, 2, 3]      0.000027
# 14  1.129572  0.733065  1.129572  0.911029  0.450680  [1, 2, 3]      0.000023
# 15  0.613215  1.150276  0.613215  0.697413  0.435676  [1, 2, 3]      0.000030
# 16  0.081656  1.043607  0.081656  0.064190  0.470521  [1, 2, 3]      0.000023
# 17  0.784752  1.121587  0.784752  0.967955  0.467454  [1, 2, 3]      0.000029
# 18  0.458239  1.187588  0.458239  0.527900  0.474522  [1, 2, 3]      0.000027
# 19  1.058431  0.414188  1.058431  0.196753  0.319209  [1, 2, 3]      0.000027
# 20  1.159214  0.334449  1.159214  0.477283  0.461971  [1, 2, 3]      0.000027
# 21  1.111950  0.226088  1.111950  0.387318  0.449510  [1, 2, 3]      0.000023
# 22  1.031507  0.094990  1.031507  0.062894  0.446533  [1, 2, 3]      0.000027
# 23  1.061323  0.091660  1.061323  0.115687  0.481826  [1, 2, 3]      0.000029
# 24  1.150073  0.725603  1.150073  0.940506  0.473491  [1, 2, 3]      0.000026
# 25  1.008932  0.965383  1.008932  0.856070  0.475593  [1, 2, 3]      0.000025
# 26  0.438067  0.953203  0.438067  0.018500  0.209229  [1, 2, 3]      0.000044
# 27  1.194647  0.464704  1.194647  0.549109  0.483780  [1, 2, 3]      0.000025
# 28  0.619828  0.872645  0.619828  0.235445  0.153223  [1, 2, 3]      0.000025
# 29  0.251951  1.146416  0.251951  0.472680  0.479382  [1, 2, 3]      0.000024
# 30  0.064220  1.042061  0.064220  0.034711  0.483734  [1, 2, 3]      0.000026
# 31  0.787181  0.635315  0.787181  0.036333  0.100783  [1, 2, 3]      0.000023
# 32  1.016832  0.099210  1.016832  0.042327  0.427747  [1, 2, 3]      0.000023
#
#     xopt_error               a
# 1        False             NaN
# 2        False             NaN
# 3        False  dummy_constant
# 4        False  dummy_constant
# 5        False  dummy_constant
# 6        False  dummy_constant
# 7        False  dummy_constant
# 8        False  dummy_constant
# 9        False  dummy_constant
# 10       False  dummy_constant
# 11       False  dummy_constant
# 12       False  dummy_constant
# 13       False  dummy_constant
# 14       False  dummy_constant
# 15       False  dummy_constant
# 16       False  dummy_constant
# 17       False  dummy_constant
# 18       False  dummy_constant
# 19       False  dummy_constant
# 20       False  dummy_constant
# 21       False  dummy_constant
# 22       False  dummy_constant
# 23       False  dummy_constant
# 24       False  dummy_constant
# 25       False  dummy_constant
# 26       False  dummy_constant
# 27       False  dummy_constant
# 28       False  dummy_constant
# 29       False  dummy_constant
# 30       False  dummy_constant
# 31       False  dummy_constant
# 32       False  dummy_constant

# %%
# plot results
ax = X.data.plot("x1", "x2")
ax.set_aspect("equal")
